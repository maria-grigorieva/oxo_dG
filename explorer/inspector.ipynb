# %%
from pathlib import Path
from inspect_nanopore_data import inspect_nanopore_data

# %%
inspect_nanopore_data(
    bam_path=Path("../input_files/bam_pass/barcode06/FBA01901_bam_pass_c5d75dbd_b3bf4d07_0.bam"),
    pod5_dir=Path("../input_files/pod5"),
    fastq_path=Path("../input_files/fastq_pass/barcode06/FBA01901_fastq_pass_c5d75dbd_b3bf4d07_0.fastq")
)
# Out:
# === Inspecting Nanopore dataset ===
# BAM: ../input_files/bam_pass/barcode06/FBA01901_bam_pass_c5d75dbd_b3bf4d07_0.bam
# POD5 dir: ../input_files/pod5
# FASTQ: ../input_files/fastq_pass/barcode06/FBA01901_fastq_pass_c5d75dbd_b3bf4d07_0.fastq
#
# Total BAM reads (first 5 shown): 5
#                                 read_id ref_name  ref_start ref_end strand  \
# 0  2d62e275-999b-4061-b65d-88e4cacdb99b     None         -1    None      +
# 1  81950bac-2c33-4c6b-bca7-e5531aabbeb1     None         -1    None      +
# 2  d6faca93-5c44-4148-aeee-161a8bc19e03     None         -1    None      +
# 3  756caaca-7804-42de-8bc4-32f4fa686f5d     None         -1    None      +
# 4  e2c7f6ef-e64f-4438-848c-4c05223d0c23     None         -1    None      +
#
#                                                 tags
# 0  {'BC': 'SQK-NBD114-24_barcode06', 'qs': 14.595...
# 1  {'BC': 'SQK-NBD114-24_barcode06', 'qs': 19.243...
# 2  {'BC': 'SQK-NBD114-24_barcode06', 'qs': 39.748...
# 3  {'BC': 'SQK-NBD114-24_barcode06', 'qs': 20.507...
# 4  {'BC': 'SQK-NBD114-24_barcode06', 'qs': 29.048...
#
# Total POD5 reads (first 5 shown):
#    2ec518d6-a726-4bcd-85b9-d47f28c89783
#    fec32aba-7ea5-4fd1-a6fe-75892106e944
#    01d16b88-9bd6-461a-9857-2b019fc653aa
#    61aaf53d-69e6-4eaf-91cd-302c6d384703
#    fa8aaea2-22a5-4210-8cab-ddadd4ce4fcd
#
# Total FASTQ reads: 1169
# First 5 read_ids: ['81950bac-2c33-4c6b-bca7-e5531aabbeb1', '43c19983-75c1-40cd-9a17-aa900e141993', '1c88eacd-7bc0-47f8-8020-58f3af2e6b3c', 'e2c7f6ef-e64f-4438-848c-4c05223d0c23', 'b1cc10bc-8b72-468c-8c48-fbb1c1640c43']
#
# === Intersection Summary ===
# Common between BAM & POD5: 0
# Common between BAM & FASTQ: 5
# Common between POD5 & FASTQ: 0
#
# Example signal for read: 2ec518d6-a726-4bcd-85b9-d47f28c89783
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 inspect_nanopore_data(
#       2     bam_path=Path("../input_files/bam_pass/barcode06/FBA01901_bam_pass_c5d75dbd_b3bf4d07_0.bam"),
#       3     pod5_dir=Path("../input_files/pod5"),
#       4     fastq_path=Path("../input_files/fastq_pass/barcode06/FBA01901_fastq_pass_c5d75dbd_b3bf4d07_0.fastq")
#       5 )
#
# File ~/PycharmProjects/oxo_dG/explorer/inspect_nanopore_data.py:71, in inspect_nanopore_data(bam_path, pod5_dir, fastq_path, max_reads)
#      69 print(f"\nExample signal for read: {example_id}")
#      70 reader = Reader(next(Path(pod5_dir).glob("*.pod5")))
# ---> 71 read = reader.get_read(example_id)
#      72 print("Signal length:", len(read.signal))
#      73 print("Signal (first 20 points):", read.signal[:20])
#
# AttributeError: 'Reader' object has no attribute 'get_read'
